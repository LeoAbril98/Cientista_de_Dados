# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'
r = requests.get(url)
df = r.json()

df_pvl = pd.DataFrame(df['items'])
RJ_pvl = df_pvl[df_pvl['uf'] == 'RJ']
RJ_pvl
# Out:
#       id_pleito tipo_interessado            interessado  cod_ibge  uf  \
# 81         5290        Município      Casimiro de Abreu   3301306  RJ
# 277       61009        Município         Rio das Flores   3304508  RJ
# 353       66228        Município    São Pedro da Aldeia   3305208  RJ
# 846        6363        Município              Rio Claro   3304409  RJ
# 892        7907        Município               Mesquita   3302858  RJ
# ...         ...              ...                    ...       ...  ..
# 4650       9898           Estado         Rio de Janeiro        33  RJ
# 4707      13229        Município          Nova Friburgo   3303401  RJ
# 4917      38893        Município        Paty do Alferes   3303856  RJ
# 4945      11338        Município        Duque de Caxias   3301702  RJ
# 4957       9205        Município  Campos dos Goytacazes   3301009  RJ
#
#                    num_pvl                          status  \
# 81                    None                        Deferido
# 277   PVL02.007214/2022-19  Arquivado por decurso de prazo
# 353   PVL02.003177/2023-42               Deferido (PVL-IF)
# 846                   None                    Regularizado
# 892                   None                        Deferido
# ...                    ...                             ...
# 4650                  None                        Deferido
# 4707                  None                        Deferido
# 4917  PVL02.007600/2019-05               Deferido (PVL-IF)
# 4945                  None                    Regularizado
# 4957                  None                        Deferido
#
#               num_processo        data_protocolo                tipo_operacao  \
# 81    17944.000078/2014-81  2014-11-28T02:00:00Z  Operação contratual interna
# 277   17944.103071/2022-20  2022-08-12T18:48:50Z  Operação contratual interna
# 353                   None                  None  Operação contratual interna
# 846   17944.000328/2008-34  2011-06-01T03:00:00Z  Operação contratual interna
# 892   17944.000675/2010-81  2010-09-06T03:00:00Z  Operação contratual interna
# ...                    ...                   ...                          ...
# 4650  17944.001076/2010-85  2011-05-25T03:00:00Z  Operação contratual interna
# 4707  17944.001968/2006-08  2007-01-18T02:00:00Z  Operação contratual interna
# 4917                  None                  None  Operação contratual interna
# 4945  17944.001415/2006-47  2007-02-28T03:00:00Z  Operação contratual interna
# 4957  17944.000926/2013-71  2013-12-20T02:00:00Z  Operação contratual interna
#
#                                              finalidade  \
# 81    PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 277                                      Infraestrutura
# 353                                      Infraestrutura
# 846          Regularização de Dívida - Energia Elétrica
# 892                                               PNAFM
# ...                                                 ...
# 4650                                              Saúde
# 4707                                            Provias
# 4917     Aquisição de máquinas, equipamentos e veículos
# 4945         Regularização de Dívida - Energia Elétrica
# 4957  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
#
#                           tipo_credor  \
# 81    Instituição Financeira Nacional
# 277   Instituição Financeira Nacional
# 353   Instituição Financeira Nacional
# 846               Empresa Não Estatal
# 892   Instituição Financeira Nacional
# ...                               ...
# 4650  Instituição Financeira Nacional
# 4707  Instituição Financeira Nacional
# 4917  Instituição Financeira Nacional
# 4945              Empresa Não Estatal
# 4957  Instituição Financeira Nacional
#
#                                               credor moeda         valor  \
# 81                           Caixa Econômica Federal  Real  1.502463e+07
# 277                          Caixa Econômica Federal  Real  6.000000e+06
# 353                              Banco do Brasil S/A  Real  5.500000e+06
# 846             Light - Serviços de Eletricidade S/A  Real  6.733231e+06
# 892                          Caixa Econômica Federal  Real  5.106563e+06
# ...                                              ...   ...           ...
# 4650                             Banco do Brasil S/A  Real  1.328000e+08
# 4707                             Banco do Brasil S/A  Real  1.976972e+06
# 4917  Agência de Fomento do Estado do Rio de Janeiro  Real  3.512000e+06
# 4945            Light - Serviços de Eletricidade S/A  Real  5.532310e+06
# 4957                         Caixa Econômica Federal  Real  3.000000e+08
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 81                   1                      0  12/12/2014
# 277                  0                      0  10/02/2023
# 353                  0                      0  12/09/2023
# 846                  0                      0  22/07/2011
# 892                  1                      0  20/09/2010
# ...                ...                    ...         ...
# 4650                 0                      0  07/06/2011
# 4707                 0                      0  15/02/2007
# 4917                 0                      1  30/10/2019
# 4945                 0                      0  13/03/2007
# 4957                 0                      0  26/12/2013
#
# [64 rows x 18 columns]

# %%
# 2) Seu código aqui

RJ_pvl.status.value_counts()
# Out:
# status
# Deferido                                                 24
# Arquivado                                                11
# Regularizado                                             10
# Encaminhado à PGFN com manifestação técnica favorável     7
# Arquivado por decurso de prazo                            6
# Deferido (PVL-IF)                                         5
# Arquivado a pedido                                        1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui

RJ_pvl.loc[:, 'ano_status'] = RJ_pvl['data_status'].str.split(pat='/').str.get(2)

RJ_pvl
# Out:
#       id_pleito tipo_interessado            interessado  cod_ibge  uf  \
# 81         5290        Município      Casimiro de Abreu   3301306  RJ
# 277       61009        Município         Rio das Flores   3304508  RJ
# 353       66228        Município    São Pedro da Aldeia   3305208  RJ
# 846        6363        Município              Rio Claro   3304409  RJ
# 892        7907        Município               Mesquita   3302858  RJ
# ...         ...              ...                    ...       ...  ..
# 4650       9898           Estado         Rio de Janeiro        33  RJ
# 4707      13229        Município          Nova Friburgo   3303401  RJ
# 4917      38893        Município        Paty do Alferes   3303856  RJ
# 4945      11338        Município        Duque de Caxias   3301702  RJ
# 4957       9205        Município  Campos dos Goytacazes   3301009  RJ
#
#                    num_pvl                          status  \
# 81                    None                        Deferido
# 277   PVL02.007214/2022-19  Arquivado por decurso de prazo
# 353   PVL02.003177/2023-42               Deferido (PVL-IF)
# 846                   None                    Regularizado
# 892                   None                        Deferido
# ...                    ...                             ...
# 4650                  None                        Deferido
# 4707                  None                        Deferido
# 4917  PVL02.007600/2019-05               Deferido (PVL-IF)
# 4945                  None                    Regularizado
# 4957                  None                        Deferido
#
#               num_processo        data_protocolo                tipo_operacao  \
# 81    17944.000078/2014-81  2014-11-28T02:00:00Z  Operação contratual interna
# 277   17944.103071/2022-20  2022-08-12T18:48:50Z  Operação contratual interna
# 353                   None                  None  Operação contratual interna
# 846   17944.000328/2008-34  2011-06-01T03:00:00Z  Operação contratual interna
# 892   17944.000675/2010-81  2010-09-06T03:00:00Z  Operação contratual interna
# ...                    ...                   ...                          ...
# 4650  17944.001076/2010-85  2011-05-25T03:00:00Z  Operação contratual interna
# 4707  17944.001968/2006-08  2007-01-18T02:00:00Z  Operação contratual interna
# 4917                  None                  None  Operação contratual interna
# 4945  17944.001415/2006-47  2007-02-28T03:00:00Z  Operação contratual interna
# 4957  17944.000926/2013-71  2013-12-20T02:00:00Z  Operação contratual interna
#
#                                              finalidade  \
# 81    PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 277                                      Infraestrutura
# 353                                      Infraestrutura
# 846          Regularização de Dívida - Energia Elétrica
# 892                                               PNAFM
# ...                                                 ...
# 4650                                              Saúde
# 4707                                            Provias
# 4917     Aquisição de máquinas, equipamentos e veículos
# 4945         Regularização de Dívida - Energia Elétrica
# 4957  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
#
#                           tipo_credor  \
# 81    Instituição Financeira Nacional
# 277   Instituição Financeira Nacional
# 353   Instituição Financeira Nacional
# 846               Empresa Não Estatal
# 892   Instituição Financeira Nacional
# ...                               ...
# 4650  Instituição Financeira Nacional
# 4707  Instituição Financeira Nacional
# 4917  Instituição Financeira Nacional
# 4945              Empresa Não Estatal
# 4957  Instituição Financeira Nacional
#
#                                               credor moeda         valor  \
# 81                           Caixa Econômica Federal  Real  1.502463e+07
# 277                          Caixa Econômica Federal  Real  6.000000e+06
# 353                              Banco do Brasil S/A  Real  5.500000e+06
# 846             Light - Serviços de Eletricidade S/A  Real  6.733231e+06
# 892                          Caixa Econômica Federal  Real  5.106563e+06
# ...                                              ...   ...           ...
# 4650                             Banco do Brasil S/A  Real  1.328000e+08
# 4707                             Banco do Brasil S/A  Real  1.976972e+06
# 4917  Agência de Fomento do Estado do Rio de Janeiro  Real  3.512000e+06
# 4945            Light - Serviços de Eletricidade S/A  Real  5.532310e+06
# 4957                         Caixa Econômica Federal  Real  3.000000e+08
#
#       pvl_assoc_divida  pvl_contradado_credor data_status ano_status
# 81                   1                      0  12/12/2014       2014
# 277                  0                      0  10/02/2023       2023
# 353                  0                      0  12/09/2023       2023
# 846                  0                      0  22/07/2011       2011
# 892                  1                      0  20/09/2010       2010
# ...                ...                    ...         ...        ...
# 4650                 0                      0  07/06/2011       2011
# 4707                 0                      0  15/02/2007       2007
# 4917                 0                      1  30/10/2019       2019
# 4945                 0                      0  13/03/2007       2007
# 4957                 0                      0  26/12/2013       2013
#
# [64 rows x 19 columns]

# %%
# 4)

RJ_pvl.ano_status.value_counts()
# Out:
# ano_status
# 2008    9
# 2011    7
# 2012    7
# 2013    6
# 2007    6
# 2023    5
# 2009    4
# 2010    4
# 2019    3
# 2020    3
# 2016    2
# 2014    2
# 2015    2
# 2002    1
# 2022    1
# 2018    1
# 2006    1
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
df_pvl
# Out:
#       id_pleito tipo_interessado                 interessado  cod_ibge  uf  \
# 0         63735        Município                   Forquilha   2304350  CE
# 1         65995        Município                      Maceió   2704302  AL
# 2         66665        Município                    Campinas   3509502  SP
# 3         65370        Município        Santana da Boa Vista   4317004  RS
# 4         51271        Município               Dois Vizinhos   4107207  PR
# ...         ...              ...                         ...       ...  ..
# 4995      27897        Município  Santo Antônio do Aracanguá   3548054  SP
# 4996      28192        Município                     Colombo   4105805  PR
# 4997      28523        Município               Santa Cecília   4215505  SC
# 4998      28056        Município                 Brasilândia   5002308  MS
# 4999      29134        Município               Muitos Capões   4312617  RS
#
#                    num_pvl                                    status  \
# 0     PVL02.000825/2023-17                         Deferido (PVL-IF)
# 1     PVL02.000568/2023-13           Em retificação pelo interessado
# 2     PVL02.002498/2023-20           Em retificação pelo interessado
# 3     PVL02.002462/2023-46  Em retificação pelo interessado (PVL-IF)
# 4     PVL02.001479/2021-14                                  Deferido
# ...                    ...                                       ...
# 4995  PVL02.000529/2018-41                         Deferido (PVL-IF)
# 4996  PVL02.000545/2018-33                                  Deferido
# 4997  PVL02.001093/2018-15                         Deferido (PVL-IF)
# 4998  PVL02.000665/2018-31                         Deferido (PVL-IF)
# 4999  PVL02.001687/2018-18                         Deferido (PVL-IF)
#
#               num_processo        data_protocolo  \
# 0                     None                  None
# 1     17944.103616/2023-89  2023-07-27T16:11:14Z
# 2     17944.104410/2023-76  2023-09-12T18:27:55Z
# 3                     None                  None
# 4     17944.104586/2021-66  2021-12-17T12:37:23Z
# ...                    ...                   ...
# 4995                  None                  None
# 4996  17944.103526/2018-21  2018-04-26T16:16:41Z
# 4997                  None                  None
# 4998                  None                  None
# 4999                  None                  None
#
#                                           tipo_operacao  \
# 0                           Operação contratual interna
# 1                           Operação contratual interna
# 2     Operação contratual interna (com garantia da U...
# 3                           Operação contratual interna
# 4                           Operação contratual interna
# ...                                                 ...
# 4995                        Operação contratual interna
# 4996                        Operação contratual interna
# 4997                        Operação contratual interna
# 4998                        Operação contratual interna
# 4999                        Operação contratual interna
#
#                                              finalidade  \
# 0                                        Infraestrutura
# 1                                                 PNAFM
# 2                                                  PMAT
# 3                                        Infraestrutura
# 4                                        Multissetorial
# ...                                                 ...
# 4995                                     Infraestrutura
# 4996  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 4997                                     Infraestrutura
# 4998     Aquisição de máquinas, equipamentos e veículos
# 4999     Aquisição de máquinas, equipamentos e veículos
#
#                           tipo_credor  \
# 0     Instituição Financeira Nacional
# 1     Instituição Financeira Nacional
# 2     Instituição Financeira Nacional
# 3     Instituição Financeira Nacional
# 4     Instituição Financeira Nacional
# ...                               ...
# 4995  Instituição Financeira Nacional
# 4996  Instituição Financeira Nacional
# 4997  Instituição Financeira Nacional
# 4998  Instituição Financeira Nacional
# 4999  Instituição Financeira Nacional
#
#                                                  credor moeda       valor  \
# 0                                   Banco do Brasil S/A  Real   1971000.0
# 1                               Caixa Econômica Federal  Real  25000000.0
# 2     Banco Nacional de Desenvolvimento Econômico e ...  Real  65838603.0
# 3                               Caixa Econômica Federal  Real  10000000.0
# 4                      Agência de Fomento do Paraná S/A  Real  13000000.0
# ...                                                 ...   ...         ...
# 4995          Agência de Fomento do Estado de São Paulo  Real   1500000.0
# 4996   Banco Regional de Desenvolvimento do Extremo Sul  Real  19000000.0
# 4997  Agência de Fomento do Estado de Santa Catarina...  Real   2000000.0
# 4998                                Banco do Brasil S/A  Real   1700000.0
# 4999                                Banco do Brasil S/A  Real    630000.0
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 0                    0                      1  29/05/2023
# 1                    0                      0  03/08/2023
# 2                    0                      0  16/11/2023
# 3                    0                      0  13/11/2023
# 4                    0                      1  29/12/2021
# ...                ...                    ...         ...
# 4995                 0                      0  22/03/2018
# 4996                 0                      1  02/05/2018
# 4997                 0                      1  22/06/2018
# 4998                 1                      1  29/03/2018
# 4999                 1                      1  26/04/2019
#
# [5000 rows x 18 columns]

# %%
#1) Seu código aqui

def consulta_dado(uf, tipo_interessado):
    dados_consulta = df_pvl[(df_pvl['uf'] == uf) & (df_pvl['tipo_interessado'] == tipo_interessado)]
    return dados_consulta

uf = 'MG'
tipo_interessado = 'Estado'

resultado_consulta = consulta_dado(uf, tipo_interessado)

MG = pd.DataFrame(resultado_consulta)
MG
# Out:
#       id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 138        4926           Estado  Minas Gerais        31  MG
# 923        7280           Estado  Minas Gerais        31  MG
# 1307       7435           Estado  Minas Gerais        31  MG
# 1494      10338           Estado  Minas Gerais        31  MG
# 1872       5828           Estado  Minas Gerais        31  MG
# 2484      13618           Estado  Minas Gerais        31  MG
# 3920      11054           Estado  Minas Gerais        31  MG
# 4079      20534           Estado  Minas Gerais        31  MG
# 4926      11328           Estado  Minas Gerais        31  MG
#
#                    num_pvl                                             status  \
# 138                   None                                          Arquivado
# 923                   None                                           Deferido
# 1307                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1494                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1872                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2484                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3920                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4079  00000.000000/2017-69                     Arquivado por decurso de prazo
# 4926                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#               num_processo        data_protocolo  \
# 138   10951.000367/1998-24  1998-05-12T03:00:00Z
# 923   17944.000537/2010-01  2010-06-24T03:00:00Z
# 1307  17944.000576/2009-66  2009-05-26T03:00:00Z
# 1494  17944.001175/2009-23  2009-09-22T03:00:00Z
# 1872  17944.000208/2013-02  2013-07-16T03:00:00Z
# 2484  19405.000037/2006-15  2009-02-26T03:00:00Z
# 3920  17944.001346/2012-10  2012-10-29T02:00:00Z
# 4079  17944.001113/2015-60  2017-07-26T03:00:00Z
# 4926  17944.001412/2012-51  2012-12-11T02:00:00Z
#
#                                           tipo_operacao  \
# 138   Operação contratual externa (com garantia da U...
# 923                         Operação contratual interna
# 1307  Operação contratual externa (com garantia da U...
# 1494  Operação contratual interna (com garantia da U...
# 1872  Operação contratual interna (com garantia da U...
# 2484  Operação contratual externa (com garantia da U...
# 3920  Operação contratual interna (com garantia da U...
# 4079                        Operação contratual interna
# 4926  Operação contratual interna (com garantia da U...
#
#                                              finalidade  \
# 138                                      Infraestrutura
# 923                                      Infraestrutura
# 1307                       Fortalecimento Institucional
# 1494  PEF - Programa Emergencial de Financiamento do...
# 1872                                     Infraestrutura
# 2484                                     Multissetorial
# 3920                                         Proinveste
# 4079                                               PMAE
# 4926                                     Multissetorial
#
#                                tipo_credor  \
# 138   Instituição Financeira Internacional
# 923        Instituição Financeira Nacional
# 1307  Instituição Financeira Internacional
# 1494       Instituição Financeira Nacional
# 1872       Instituição Financeira Nacional
# 2484  Instituição Financeira Internacional
# 3920       Instituição Financeira Nacional
# 4079       Instituição Financeira Nacional
# 4926       Instituição Financeira Nacional
#
#                                                  credor          moeda  \
# 138   Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 923   Banco Nacional de Desenvolvimento Econômico e ...           Real
# 1307            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 1494                                Banco do Brasil S/A           Real
# 1872                                Banco do Brasil S/A           Real
# 2484            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 3920  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4079  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4926                                Banco do Brasil S/A           Real
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 138   1.650000e+08                 0                      0  24/07/2002
# 923   3.488900e+07                 1                      0  25/06/2010
# 1307  4.000000e+07                 1                      0  10/06/2009
# 1494  1.781800e+08                 1                      0  08/10/2009
# 1872  1.500000e+09                 1                      0  12/08/2013
# 2484  1.000000e+07                 1                      0  12/03/2009
# 3920  1.326390e+09                 1                      0  02/01/2013
# 4079  7.668000e+06                 0                      0  16/03/2018
# 4926  3.653733e+09                 1                      0  03/01/2013

# %%
# 2) Seu código aqui

MG.status.value_counts()

#resposta = 0 solicitações com o status pedido
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    6
# Arquivado                                                1
# Deferido                                                 1
# Arquivado por decurso de prazo                           1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui

BA_pvl = df_pvl[df_pvl['uf'] == 'BA']
BA_pvl_municipios = BA_pvl[BA_pvl['tipo_interessado'] == 'Município']

BA_pvl_municipios.interessado.value_counts()
# Out:
# interessado
# Salvador                6
# Vitória da Conquista    4
# Barreiras               4
# Lauro de Freitas        4
# Barra da Estiva         3
#                        ..
# Mirangaba               1
# Ribeirão do Largo       1
# Barra                   1
# Morro do Chapéu         1
# Amargosa                1
# Name: count, Length: 144, dtype: int64

# %%
# 4) Seu código aqui

BA_pvl_estado = BA_pvl[BA_pvl['tipo_interessado'] == 'Estado']
BA_pvl_estado.to_csv('BA_pvl_ESTADO.csv', index = False, sep=';', decimal=',')
